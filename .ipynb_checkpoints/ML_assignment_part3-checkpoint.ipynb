# %%
## Importing packages - Please DO NOT alter this box ##
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data.sampler import WeightedRandomSampler
torch.manual_seed(0)

from captum.attr import IntegratedGradients
from captum.attr import DeepLift
from captum.attr import NoiseTunnel
from captum.attr import visualization as viz

import torchvision
from torchvision import datasets, transforms
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

import os
import imageio
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from tqdm import tqdm
from scipy.ndimage import binary_erosion
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns

import wandb #comment this out if you are not using weights and biases
import random #comment this out if you are not using weights and biases

# Set device to cuda if it's available otherwise default to "cpu"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
images = "/projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species"

# %%
def _get_weights(subset,full_dataset):
    ys = np.array([y for _, y in subset])
    counts = np.bincount(ys)
    label_weights = 1.0 / counts
    weights = label_weights[ys]

    print("Number of images per class:")
    for c, n, w in zip(full_dataset.classes, counts, label_weights):
        print(f"\t{c}:\tn={n}\tweight={w}")
        
    return weights

# %%
transform = transforms.Compose([
            transforms.Resize([224,224]), # Resize the image as our model is optimized for 224x224 pixels
            #transforms.RandomPerspective(distortion_scale=0.6, p=1.0),
            transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
            #transforms.ColorJitter(brightness=.5, hue=.3),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]) # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences))

all_images = datasets.ImageFolder(images, transform )

train_size = int(0.7 * len(all_images))
val_size = int(0.15 * len(all_images))
test_size = len(all_images) - (train_size + val_size)
train_set, val_set, test_set = torch.utils.data.random_split(all_images, [train_size, val_size, test_size])
train_weights = _get_weights(train_set,all_images)
train_sampler = WeightedRandomSampler(train_weights, len(train_weights))

batchsize = 48
learning_rate=1e-3
epochs=5

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)
# Out:
# Number of images per class:
# 	beluga:	n=465	weight=0.002150537634408602
# 	common_dolphin:	n=50	weight=0.02
# 	false_killer_whale:	n=716	weight=0.0013966480446927375
# 	fin_whale:	n=116	weight=0.008620689655172414
# 	gray_whale:	n=44	weight=0.022727272727272728
# 	humpback_whale:	n=564	weight=0.0017730496453900709

# %%
## Getting our model and transferring it to the GPU
from torchvision.models import ResNet18_Weights
model = torchvision.models.resnet18(weights='DEFAULT', progress = True).to(device)
model.fc = nn.Linear(model.fc.in_features, 6)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Brandy-HappyWhale-SpeciesDataset-hyperparameters_mod3", ##update this with your name
    config={"learning rate":.001, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 5, "batch_size":48}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()

plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

# predict the test dataset
def predict(model, dataset):
    dataset_prediction = []
    dataset_groundtruth = []
    model = model
    with torch.no_grad():
        for x, y_true in dataset:
            inp = x[None]
            y_pred = model(inp)
            dataset_prediction.append(y_pred.argmax().cpu().numpy())
            dataset_groundtruth.append(y_true)
    
    return np.array(dataset_prediction), np.array(dataset_groundtruth)
            
    # create seaborn heatmap with required labels
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels)
    ax.set_title(title)

# Plot confusion matrix 
# orginally from Runqi Yang; 
# see https://gist.github.com/hitvoice/36cf44689065ca9b927431546381a3f7
def cm_analysis(y_true, y_pred, title, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale']
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
                              
    x_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for x-axis
    y_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for y-axis
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels, cmap = "viridis")
    ax.set_title(title)

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/bcorwin/.netrc.
# wandb: Currently logged in as: bcorwin (BGMP_HappyWhale) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/home/bcorwin/HappyWhaleClassifier/wandb/run-20260308_110617-3eqtgrpi</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/3eqtgrpi' target="_blank">Brandy-HappyWhale-SpeciesDataset-hyperparameters_mod3</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/3eqtgrpi' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/3eqtgrpi</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 20.83%
# Epoch [1/5] | Batch #2 | Batch Accuracy 41.67%
# Epoch [1/5] | Batch #3 | Batch Accuracy 49.31%
# Epoch [1/5] | Batch #4 | Batch Accuracy 56.25%
# Epoch [1/5] | Batch #5 | Batch Accuracy 61.67%
# Epoch [1/5] | Batch #6 | Batch Accuracy 63.89%
# Epoch [1/5] | Batch #7 | Batch Accuracy 64.29%
# Epoch [1/5] | Batch #8 | Batch Accuracy 66.41%
# Epoch [1/5] | Batch #9 | Batch Accuracy 68.29%
# Epoch [1/5] | Batch #10 | Batch Accuracy 68.75%
# Epoch [1/5] | Batch #11 | Batch Accuracy 69.89%
# Epoch [1/5] | Batch #12 | Batch Accuracy 70.66%
# Epoch [1/5] | Batch #13 | Batch Accuracy 72.12%
# Epoch [1/5] | Batch #14 | Batch Accuracy 72.77%
# Epoch [1/5] | Batch #15 | Batch Accuracy 73.61%
# Epoch [1/5] | Batch #16 | Batch Accuracy 74.22%
# Epoch [1/5] | Batch #17 | Batch Accuracy 75.00%
# Epoch [1/5] | Batch #18 | Batch Accuracy 75.12%
# Epoch [1/5] | Batch #19 | Batch Accuracy 75.77%
# Epoch [1/5] | Batch #20 | Batch Accuracy 76.25%
# Epoch [1/5] | Batch #21 | Batch Accuracy 76.49%
# Epoch [1/5] | Batch #22 | Batch Accuracy 76.89%
# Epoch [1/5] | Batch #23 | Batch Accuracy 77.54%
# Epoch [1/5] | Batch #24 | Batch Accuracy 78.21%
# Epoch [1/5] | Batch #25 | Batch Accuracy 78.58%
# Epoch [1/5] | Batch #26 | Batch Accuracy 79.17%
# Epoch [1/5] | Batch #27 | Batch Accuracy 79.48%
# Epoch [1/5] | Batch #28 | Batch Accuracy 79.91%
# Epoch [1/5] | Batch #29 | Batch Accuracy 80.46%
# Epoch [1/5] | Batch #30 | Batch Accuracy 80.62%
# Epoch [1/5] | Batch #31 | Batch Accuracy 81.05%
# Epoch [1/5] | Batch #32 | Batch Accuracy 81.51%
# Epoch [1/5] | Batch #33 | Batch Accuracy 81.94%
# Epoch [1/5] | Batch #34 | Batch Accuracy 82.23%
# Epoch [1/5] | Batch #35 | Batch Accuracy 82.68%
# Epoch [1/5] | Batch #36 | Batch Accuracy 82.99%
# Epoch [1/5] | Batch #37 | Batch Accuracy 83.33%
# Epoch [1/5] | Batch #38 | Batch Accuracy 83.66%
# Epoch [1/5] | Batch #39 | Batch Accuracy 83.92%
# Epoch [1/5] | Batch #40 | Batch Accuracy 84.17%
# Epoch [1/5] Train Loss: 0.4433 | Train Acc: 84.17% | Val Acc: 81.77% | Val Loss: 0.67%
# Epoch [2/5] | Batch #41 | Batch Accuracy 95.83%
# Epoch [2/5] | Batch #42 | Batch Accuracy 96.88%
# Epoch [2/5] | Batch #43 | Batch Accuracy 96.53%
# Epoch [2/5] | Batch #44 | Batch Accuracy 95.31%
# Epoch [2/5] | Batch #45 | Batch Accuracy 94.17%
# Epoch [2/5] | Batch #46 | Batch Accuracy 94.44%
# Epoch [2/5] | Batch #47 | Batch Accuracy 94.35%
# Epoch [2/5] | Batch #48 | Batch Accuracy 94.01%
# Epoch [2/5] | Batch #49 | Batch Accuracy 93.52%
# Epoch [2/5] | Batch #50 | Batch Accuracy 92.92%
# Epoch [2/5] | Batch #51 | Batch Accuracy 92.80%
# Epoch [2/5] | Batch #52 | Batch Accuracy 93.06%
# Epoch [2/5] | Batch #53 | Batch Accuracy 93.11%
# Epoch [2/5] | Batch #54 | Batch Accuracy 93.45%
# Epoch [2/5] | Batch #55 | Batch Accuracy 93.75%
# Epoch [2/5] | Batch #56 | Batch Accuracy 94.01%
# Epoch [2/5] | Batch #57 | Batch Accuracy 93.87%
# Epoch [2/5] | Batch #58 | Batch Accuracy 93.87%
# Epoch [2/5] | Batch #59 | Batch Accuracy 93.64%
# Epoch [2/5] | Batch #60 | Batch Accuracy 93.54%
# Epoch [2/5] | Batch #61 | Batch Accuracy 93.45%
# Epoch [2/5] | Batch #62 | Batch Accuracy 93.37%
# Epoch [2/5] | Batch #63 | Batch Accuracy 93.48%
# Epoch [2/5] | Batch #64 | Batch Accuracy 93.23%
# Epoch [2/5] | Batch #65 | Batch Accuracy 93.33%
# Epoch [2/5] | Batch #66 | Batch Accuracy 93.35%
# Epoch [2/5] | Batch #67 | Batch Accuracy 93.44%
# Epoch [2/5] | Batch #68 | Batch Accuracy 93.38%
# Epoch [2/5] | Batch #69 | Batch Accuracy 93.25%
# Epoch [2/5] | Batch #70 | Batch Accuracy 93.26%
# Epoch [2/5] | Batch #71 | Batch Accuracy 93.28%
# Epoch [2/5] | Batch #72 | Batch Accuracy 93.36%
# Epoch [2/5] | Batch #73 | Batch Accuracy 93.43%
# Epoch [2/5] | Batch #74 | Batch Accuracy 93.57%
# Epoch [2/5] | Batch #75 | Batch Accuracy 93.63%
# Epoch [2/5] | Batch #76 | Batch Accuracy 93.40%
# Epoch [2/5] | Batch #77 | Batch Accuracy 93.30%
# Epoch [2/5] | Batch #78 | Batch Accuracy 93.42%
# Epoch [2/5] | Batch #79 | Batch Accuracy 93.54%
# Epoch [2/5] | Batch #80 | Batch Accuracy 93.49%
# Epoch [2/5] Train Loss: 0.1922 | Train Acc: 93.49% | Val Acc: 70.83% | Val Loss: 1.08%
# Epoch [3/5] | Batch #81 | Batch Accuracy 91.67%
# Epoch [3/5] | Batch #82 | Batch Accuracy 92.71%
# Epoch [3/5] | Batch #83 | Batch Accuracy 94.44%
# Epoch [3/5] | Batch #84 | Batch Accuracy 94.27%
# Epoch [3/5] | Batch #85 | Batch Accuracy 94.17%
# Epoch [3/5] | Batch #86 | Batch Accuracy 94.10%
# Epoch [3/5] | Batch #87 | Batch Accuracy 94.35%
# Epoch [3/5] | Batch #88 | Batch Accuracy 94.27%
# Epoch [3/5] | Batch #89 | Batch Accuracy 94.91%
# Epoch [3/5] | Batch #90 | Batch Accuracy 95.42%
# Epoch [3/5] | Batch #91 | Batch Accuracy 95.64%
# Epoch [3/5] | Batch #92 | Batch Accuracy 95.66%
# Epoch [3/5] | Batch #93 | Batch Accuracy 95.51%
# Epoch [3/5] | Batch #94 | Batch Accuracy 94.94%
# Epoch [3/5] | Batch #95 | Batch Accuracy 94.86%
# Epoch [3/5] | Batch #96 | Batch Accuracy 95.05%
# Epoch [3/5] | Batch #97 | Batch Accuracy 95.22%
# Epoch [3/5] | Batch #98 | Batch Accuracy 95.25%
# Epoch [3/5] | Batch #99 | Batch Accuracy 95.50%
# Epoch [3/5] | Batch #100 | Batch Accuracy 95.73%
# Epoch [3/5] | Batch #101 | Batch Accuracy 95.54%
# Epoch [3/5] | Batch #102 | Batch Accuracy 95.55%
# Epoch [3/5] | Batch #103 | Batch Accuracy 95.74%
# Epoch [3/5] | Batch #104 | Batch Accuracy 95.57%
# Epoch [3/5] | Batch #105 | Batch Accuracy 95.50%
# Epoch [3/5] | Batch #106 | Batch Accuracy 95.67%
# Epoch [3/5] | Batch #107 | Batch Accuracy 95.76%
# Epoch [3/5] | Batch #108 | Batch Accuracy 95.91%
# Epoch [3/5] | Batch #109 | Batch Accuracy 95.91%
# Epoch [3/5] | Batch #110 | Batch Accuracy 95.62%
# Epoch [3/5] | Batch #111 | Batch Accuracy 95.56%
# Epoch [3/5] | Batch #112 | Batch Accuracy 95.51%
# Epoch [3/5] | Batch #113 | Batch Accuracy 95.52%
# Epoch [3/5] | Batch #114 | Batch Accuracy 95.40%
# Epoch [3/5] | Batch #115 | Batch Accuracy 95.54%
# Epoch [3/5] | Batch #116 | Batch Accuracy 95.54%
# Epoch [3/5] | Batch #117 | Batch Accuracy 95.61%
# Epoch [3/5] | Batch #118 | Batch Accuracy 95.61%
# Epoch [3/5] | Batch #119 | Batch Accuracy 95.67%
# Epoch [3/5] | Batch #120 | Batch Accuracy 95.73%
# Epoch [3/5] Train Loss: 0.1319 | Train Acc: 95.73% | Val Acc: 57.81% | Val Loss: 2.17%
# Epoch [4/5] | Batch #121 | Batch Accuracy 95.83%
# Epoch [4/5] | Batch #122 | Batch Accuracy 96.88%
# Epoch [4/5] | Batch #123 | Batch Accuracy 96.53%
# Epoch [4/5] | Batch #124 | Batch Accuracy 96.88%
# Epoch [4/5] | Batch #125 | Batch Accuracy 96.67%
# Epoch [4/5] | Batch #126 | Batch Accuracy 97.22%
# Epoch [4/5] | Batch #127 | Batch Accuracy 96.73%
# Epoch [4/5] | Batch #128 | Batch Accuracy 96.61%
# Epoch [4/5] | Batch #129 | Batch Accuracy 95.83%
# Epoch [4/5] | Batch #130 | Batch Accuracy 96.04%
# Epoch [4/5] | Batch #131 | Batch Accuracy 96.21%
# Epoch [4/5] | Batch #132 | Batch Accuracy 96.35%
# Epoch [4/5] | Batch #133 | Batch Accuracy 96.63%
# Epoch [4/5] | Batch #134 | Batch Accuracy 96.43%
# Epoch [4/5] | Batch #135 | Batch Accuracy 96.53%
# Epoch [4/5] | Batch #136 | Batch Accuracy 96.35%
# Epoch [4/5] | Batch #137 | Batch Accuracy 96.32%
# Epoch [4/5] | Batch #138 | Batch Accuracy 96.30%
# Epoch [4/5] | Batch #139 | Batch Accuracy 96.16%
# Epoch [4/5] | Batch #140 | Batch Accuracy 96.04%
# Epoch [4/5] | Batch #141 | Batch Accuracy 96.23%
# Epoch [4/5] | Batch #142 | Batch Accuracy 96.31%
# Epoch [4/5] | Batch #143 | Batch Accuracy 96.38%
# Epoch [4/5] | Batch #144 | Batch Accuracy 96.44%
# Epoch [4/5] | Batch #145 | Batch Accuracy 96.50%
# Epoch [4/5] | Batch #146 | Batch Accuracy 96.63%
# Epoch [4/5] | Batch #147 | Batch Accuracy 96.76%
# Epoch [4/5] | Batch #148 | Batch Accuracy 96.80%
# Epoch [4/5] | Batch #149 | Batch Accuracy 96.77%
# Epoch [4/5] | Batch #150 | Batch Accuracy 96.67%
# Epoch [4/5] | Batch #151 | Batch Accuracy 96.64%
# Epoch [4/5] | Batch #152 | Batch Accuracy 96.68%
# Epoch [4/5] | Batch #153 | Batch Accuracy 96.72%
# Epoch [4/5] | Batch #154 | Batch Accuracy 96.81%
# Epoch [4/5] | Batch #155 | Batch Accuracy 96.73%
# Epoch [4/5] | Batch #156 | Batch Accuracy 96.76%
# Epoch [4/5] | Batch #157 | Batch Accuracy 96.79%
# Epoch [4/5] | Batch #158 | Batch Accuracy 96.82%
# Epoch [4/5] | Batch #159 | Batch Accuracy 96.74%
# Epoch [4/5] | Batch #160 | Batch Accuracy 96.82%
# Epoch [4/5] Train Loss: 0.0925 | Train Acc: 96.82% | Val Acc: 91.93% | Val Loss: 0.22%
# Epoch [5/5] | Batch #161 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #162 | Batch Accuracy 96.88%
# Epoch [5/5] | Batch #163 | Batch Accuracy 97.92%
# Epoch [5/5] | Batch #164 | Batch Accuracy 97.40%
# Epoch [5/5] | Batch #165 | Batch Accuracy 96.25%
# Epoch [5/5] | Batch #166 | Batch Accuracy 96.53%
# Epoch [5/5] | Batch #167 | Batch Accuracy 96.73%
# Epoch [5/5] | Batch #168 | Batch Accuracy 96.88%
# Epoch [5/5] | Batch #169 | Batch Accuracy 96.99%
# Epoch [5/5] | Batch #170 | Batch Accuracy 97.08%
# Epoch [5/5] | Batch #171 | Batch Accuracy 96.40%
# Epoch [5/5] | Batch #172 | Batch Accuracy 96.35%
# Epoch [5/5] | Batch #173 | Batch Accuracy 96.63%
# Epoch [5/5] | Batch #174 | Batch Accuracy 96.58%
# Epoch [5/5] | Batch #175 | Batch Accuracy 96.67%
# Epoch [5/5] | Batch #176 | Batch Accuracy 96.74%
# Epoch [5/5] | Batch #177 | Batch Accuracy 96.81%
# Epoch [5/5] | Batch #178 | Batch Accuracy 96.30%
# Epoch [5/5] | Batch #179 | Batch Accuracy 96.49%
# Epoch [5/5] | Batch #180 | Batch Accuracy 96.25%
# Epoch [5/5] | Batch #181 | Batch Accuracy 96.43%
# Epoch [5/5] | Batch #182 | Batch Accuracy 96.50%
# Epoch [5/5] | Batch #183 | Batch Accuracy 96.38%
# Epoch [5/5] | Batch #184 | Batch Accuracy 96.18%
# Epoch [5/5] | Batch #185 | Batch Accuracy 96.25%
# Epoch [5/5] | Batch #186 | Batch Accuracy 96.39%
# Epoch [5/5] | Batch #187 | Batch Accuracy 96.22%
# Epoch [5/5] | Batch #188 | Batch Accuracy 96.21%
# Epoch [5/5] | Batch #189 | Batch Accuracy 96.05%
# Epoch [5/5] | Batch #190 | Batch Accuracy 96.18%
# Epoch [5/5] | Batch #191 | Batch Accuracy 96.30%
# Epoch [5/5] | Batch #192 | Batch Accuracy 96.29%
# Epoch [5/5] | Batch #193 | Batch Accuracy 96.28%
# Epoch [5/5] | Batch #194 | Batch Accuracy 96.32%
# Epoch [5/5] | Batch #195 | Batch Accuracy 96.31%
# Epoch [5/5] | Batch #196 | Batch Accuracy 96.30%
# Epoch [5/5] | Batch #197 | Batch Accuracy 96.28%
# Epoch [5/5] | Batch #198 | Batch Accuracy 96.33%
# Epoch [5/5] | Batch #199 | Batch Accuracy 96.42%
# Epoch [5/5] | Batch #200 | Batch Accuracy 96.41%
# Epoch [5/5] Train Loss: 0.1004 | Train Acc: 96.41% | Val Acc: 91.15% | Val Loss: 0.27%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▃▂▁▁</td></tr><tr><td>validation_accuracy</td><td>▆▄▁██</td></tr><tr><td>validation_loss</td><td>▃▄█▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.10036</td></tr><tr><td>validation_accuracy</td><td>91.14583</td></tr><tr><td>validation_loss</td><td>0.26954</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Brandy-HappyWhale-SpeciesDataset-hyperparameters_mod3</strong> at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/3eqtgrpi' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/3eqtgrpi</a><br> View project at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a><br>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260308_110617-3eqtgrpi/logs</code>
# /tmp/ipykernel_2349507/3831651784.py:147: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
